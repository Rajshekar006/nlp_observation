# %%
from collections import Counter
text = "I Love NLP and I Love Python"
tokens = text.lower().split()
Counts = Counter(tokens)
total = sum(Counts.values())
unigram = {word: count/total for word, count in Counts.items()}
print(unigram)
# Out:
# {'i': 0.2857142857142857, 'love': 0.2857142857142857, 'nlp': 0.14285714285714285, 'and': 0.14285714285714285, 'python': 0.14285714285714285}
