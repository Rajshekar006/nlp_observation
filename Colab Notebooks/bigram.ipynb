# %%
from collections import Counter
t = input("enter text:").lower().split()
b = [(t[i], t[i+1]) for i in range(len(t)-1)]
wc, bc = Counter(t), Counter(b)
print("In Bigram probabilities:")
for (w1, w2), c in bc.items():
 print(f"{w1} {w2}: {c/wc[w1]:.4f}")
# Out:
# enter text:I love nlp and I love coding
# In Bigram probabilities:
# i love: 1.0000
# love nlp: 0.5000
# nlp and: 1.0000
# and i: 1.0000
# love coding: 0.5000
